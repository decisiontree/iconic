# %%
import pandas as pd
import numpy as np

# %%
data_raw = pd.read_json("test_data/data.json")

# %%
#print(data_raw.head())
print(data_raw.shape)
# Out:
# (46279, 43)

# %%
for col in data_raw.columns:
    print(data_raw[col].describe())
# Out:
# count    46279.000000
# mean         0.053437
# std          0.224905
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: afterpay_payments, dtype: float64
# count    46279.000000
# mean         0.042935
# std          0.535762
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         33.000000
# Name: android_orders, dtype: float64
# count    46279.000000
# mean         0.000562
# std          0.023696
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: apple_payments, dtype: float64
# count    46279.000000
# mean         0.190271
# std          0.190814
# min          0.000000
# 25%          0.000000
# 50%          0.150000
# 75%          0.314300
# max          1.000000
# Name: average_discount_onoffer, dtype: float64
# count    46279.000000
# mean      2357.381799
# ...

# %%
#for col in data_raw.columns:
#    print(data_raw[col].describe())
import seaborn as sns
import matplotlib.pyplot as plt

for i, col in enumerate(data_raw._get_numeric_data().columns):
    #if(i<10):
    plt.figure(i)
    sns.distplot(data_raw[col].dropna())
    plt.show()
#1. customers id duplicatoin
#2. days_since_last_order peaked at 40000, that is over 100 years. wrong data
##

# %%
# Display the facets overview visualization for this data
from IPython.core.display import display, HTML
#jsonstr = housing_train_data.to_json(orient='records')
jsonstr = pd.read_json("test_data/data.json")
#HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
HTML_TEMPLATE = """<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data =        afterpay_payments  android_orders  apple_payments  \
# 0                      0               0               0
# 1                      0               0               0
# 2                      1               0               0
# 3                      0               0               0
# 4                      0               0               0
# 5                      0               0               0
# 6                      0               0               0
# 7                      0               0               0
# 8                      0               0               0
# 9                      0               0               0
# 10                     0               0               0
# 11                     0               0               0
# ...

# %%
# Display the facets overview visualization for this data
from IPython.core.display import display, HTML
#jsonstr = housing_train_data.to_json(orient='records')
jsonstr = pd.read_json("test_data/data.json")
HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data =        afterpay_payments  android_orders  apple_payments  \
# 0                      0               0               0
# 1                      0               0               0
# 2                      1               0               0
# 3                      0               0               0
# 4                      0               0               0
# 5                      0               0               0
# 6                      0               0               0
# 7                      0               0               0
# 8                      0               0               0
# 9                      0               0               0
# 10                     0               0               0
# 11                     0               0               0
# ...
